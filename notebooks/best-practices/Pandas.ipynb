# %% [markdown]
# # Pandas Best Practices (WIP)
#
# ### References
# https://calmcode.io/pandas-pipe/introduction.html
# https://github.com/koaning/calm-notebooks
# https://github.com/wesm/pydata-book
# TODO: more...

# %%
import numpy as np
import pandas as pd
from IPython.display import display, HTML

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = 100

# %%
# csv = 'notebooks/best-practices/github_data.csv'
csv = 'https://raw.githubusercontent.com/dylanhogg/crazy-awesome-python/master/github_data.csv'
df_raw = pd.read_csv(csv)

# %%
df_raw[0:3]
# Out:
#    Unnamed: 0 category                                    githuburl  featured  \
# 0          89    ml-dl     https://github.com/tensorflow/tensorflow       NaN
# 1         407     util      https://github.com/TheAlgorithms/Python       NaN
# 2         112      nlp  https://github.com/huggingface/transformers       NaN
#
#   links  description                 _repopath     _reponame  _stars  _forks  \
# 0   NaN          NaN     tensorflow/tensorflow    tensorflow  167198   87081
# 1   NaN          NaN      TheAlgorithms/Python        Python  142291   36460
# 2   NaN          NaN  huggingface/transformers  transformers   68665   15893
#
#    _watches                                            _topics _language  \
# 0      7819  ['tensorflow', 'machine-learning', 'python', '...       C++
# 1      6016  ['python', 'algorithm', 'algorithms-implemente...    Python
# 2       845  ['nlp', 'natural-language-processing', 'pytorc...    Python
#
#                              _homepage  \
# 0               https://tensorflow.org
# 1          https://the-algorithms.com/
# 2  https://huggingface.co/transformers
#
#                                         _description  _organization  \
# 0  tensorflow: An Open Source Machine Learning Fr...     tensorflow
# 1       Python: All Algorithms implemented in Python  TheAlgorithms
# 2  🤗 Transformers: State-of-the-art Machine Learn...    huggingface
#
#   _updated_at _last_commit_date _created_at  _age_weeks  _stars_per_week
# 0  2022-08-19        2022-08-19  2015-11-07         353       472.501413
# 1  2022-08-19        2022-08-16  2016-07-16         317       447.657079
# 2  2022-08-19        2022-08-18  2018-10-29         198       345.794964

# %%
def set_dtypes(dataf: pd.DataFrame) -> pd.DataFrame:
    """Example of datetime conversion"""
    return (dataf
            .assign(last_commit_date=lambda d: pd.to_datetime(d['last_commit_date']))
            .assign(updated_at=lambda d: pd.to_datetime(d['updated_at']))
            .assign(created_at=lambda d: pd.to_datetime(d['created_at']))
           )

def drop_unnamed_columns(dataf: pd.DataFrame) -> pd.DataFrame:
    return dataf.loc[:, ~dataf.columns.str.contains('^Unnamed')]

def rename_columns(dataf: pd.DataFrame) -> pd.DataFrame:
    dataf.columns = dataf.columns.str.lstrip('_')
    dataf.columns = dataf.columns.str.replace(' ', '')
    return dataf

def filter_rows(dataf: pd.DataFrame, column, min_value) -> pd.DataFrame:
    return (dataf[dataf[column] >= min_value])
                
def calc_popularity_measure(dataf: pd.DataFrame, col_name = "popularity_measure") -> pd.DataFrame:
    """Example of assign() with string name"""
    def _calc_popularity_measure(row):
        return (row["stars"] + row["forks"] + row["watches"]) / row["age_weeks"]
    kwargs = {col_name: _calc_popularity_measure}
    return dataf.assign(**kwargs)

def calc_per_week_measures(dataf: pd.DataFrame) -> pd.DataFrame:
    """Example of apply() with result_type of expand"""
    def _calc_per_week_measures(row):
        return {
            "watches_per_week": row["watches"] / row["age_weeks"], 
            "forks_per_week": row["forks"] / row["age_weeks"] 
        }
    res = dataf.apply(_calc_per_week_measures, axis=1, result_type='expand')
    dataf[res.columns] = res
    return dataf

def calc_percentages(dataf: pd.DataFrame) -> pd.DataFrame:
    """Example of apply() with result_type of expand"""
    def _calc_percentages(row):
        return {
            "stars_percent": row["stars"] * 100 / dataf["stars"].sum(), 
            "watches_percent": row["watches"] * 100 / dataf["watches"].sum(), 
            "forks_percent": row["forks"] * 100 / dataf["forks"].sum()
        }
    res = dataf.apply(_calc_percentages, axis=1, result_type='expand')
    dataf[res.columns] = res
    return dataf

def calc_totals(dataf: pd.DataFrame, index_name= "total") -> pd.DataFrame:
    """Example """
    def _numeric_sum(col):
        return col.sum() if np.issubdtype(col.dtype, np.number) else None
    dataf.loc[index_name] = dataf.apply(_numeric_sum, axis=0) # over columns
    return dataf
    
def sort(dataf: pd.DataFrame, col_names=["popularity_measure"]) -> pd.DataFrame:
    return dataf.sort_values(by=col_names, ascending=False)

def move_col(dataf, col_name, index=0):
    cols = dataf.columns.tolist()
    cols.insert(0, cols.pop(cols.index(col_name)))
    return dataf.loc[:, cols]

# %%
df = (df_raw
      .pipe(drop_unnamed_columns)
      .pipe(rename_columns)
      .pipe(set_dtypes)
      .pipe(filter_rows, column="stars", min_value=100)
      .pipe(calc_per_week_measures)
      .pipe(calc_percentages)
      .pipe(calc_popularity_measure, col_name="popularity_measure")
      .pipe(sort, col_names=["popularity_measure"])
      .pipe(calc_totals)
      .pipe(move_col, "popularity_measure")
     )

# %%
display(df)
# Out:
#        popularity_measure category  \
# 206           5887.000000    ml-dl
# 0              742.487252    ml-dl
# 74             618.000000      web
# 1              582.861199     util
# 124            493.842105     perf
# ...                   ...      ...
# 698              0.711656     util
# 657              0.674009      geo
# 688              0.666667    graph
# 642              0.618661     util
# total        28945.120754      NaN
#
#                                             githuburl  featured links  \
# 206       https://github.com/CompVis/stable-diffusion       NaN   NaN
# 0            https://github.com/tensorflow/tensorflow       NaN   NaN
# 74               https://github.com/pyscript/pyscript       NaN   NaN
# 1             https://github.com/TheAlgorithms/Python       NaN   NaN
# 124               https://github.com/bloomberg/memray       NaN   NaN
# ...                                               ...       ...   ...
# 698              https://github.com/irmen/pyminiaudio       NaN   NaN
# 657       https://github.com/openaddresses/pyesridump       NaN   NaN
# 688    https://github.com/guyallard/markov_clustering       NaN   NaN
# 642         https://github.com/mgedmin/check-manifest       NaN   NaN
# total                                             NaN      23.0   NaN
#
#       description                                        description  \
# 206           NaN                           CompVis/stable-diffusion
# 0             NaN  tensorflow: An Open Source Machine Learning Fr...
# 74            NaN  pyscript: Home Page: https://pyscript.net  Exa...
# 1             NaN       Python: All Algorithms implemented in Python
# 124           NaN             Memray is a memory profiler for Python
# ...           ...                                                ...
# 698           NaN  pyminiaudio: python interface to the miniaudio...
# 657           NaN  pyesridump: Scrapes an ESRI MapServer REST end...
# 688           NaN     markov_clustering: markov clustering in python
# 642           NaN  check-manifest: Tool to check the completeness...
# total         0.0                                                NaN
#
#                           repopath           reponame      stars     forks  \
# 206       CompVis/stable-diffusion   stable-diffusion     5376.0     397.0
# 0            tensorflow/tensorflow         tensorflow   167198.0   87081.0
# 74               pyscript/pyscript           pyscript    14260.0    1013.0
# 1             TheAlgorithms/Python             Python   142291.0   36460.0
# 124               bloomberg/memray             memray     9086.0     244.0
# ...                            ...                ...        ...       ...
# 698              irmen/pyminiaudio        pyminiaudio      102.0      11.0
# 657       openaddresses/pyesridump         pyesridump      234.0      57.0
# 688    guyallard/markov_clustering  markov_clustering      127.0      34.0
# 642         mgedmin/check-manifest     check-manifest      263.0      36.0
# total                          NaN                NaN  4207831.0  906024.0
#
#         watches                                             topics  \
# 206       114.0                                                 []
# 0        7819.0  ['tensorflow', 'machine-learning', 'python', '...
# 74        177.0                   ['python', 'html', 'javascript']
# 1        6016.0  ['python', 'algorithm', 'algorithms-implemente...
# 124        53.0  ['memory', 'memory-leak', 'memory-leak-detecti...
# ...         ...                                                ...
# 698         3.0                                                 []
# 657        15.0                                                 []
# 688         9.0  ['markov-clustering', 'clustering', 'python', ...
# 642         6.0                                                 []
# total  115310.0                                                NaN
#
#                language                                           homepage  \
# 206    Jupyter Notebook                                                NaN
# 0                   C++                             https://tensorflow.org
# 74           TypeScript  https://community.anaconda.cloud/c/tech-topics...
# 1                Python                        https://the-algorithms.com/
# 124              Python                https://bloomberg.github.io/memray/
# ...                 ...                                                ...
# 698                   C                                                NaN
# 657              Python                                                NaN
# 688              Python                                                NaN
# 642              Python                  https://pypi.org/p/check-manifest
# total               NaN                                                NaN
#
#       description                                        description  \
# 206           NaN                           CompVis/stable-diffusion
# 0             NaN  tensorflow: An Open Source Machine Learning Fr...
# 74            NaN  pyscript: Home Page: https://pyscript.net  Exa...
# 1             NaN       Python: All Algorithms implemented in Python
# 124           NaN             Memray is a memory profiler for Python
# ...           ...                                                ...
# 698           NaN  pyminiaudio: python interface to the miniaudio...
# 657           NaN  pyesridump: Scrapes an ESRI MapServer REST end...
# 688           NaN     markov_clustering: markov clustering in python
# 642           NaN  check-manifest: Tool to check the completeness...
# total         0.0                                                NaN
#
#         organization updated_at last_commit_date created_at  age_weeks  \
# 206          CompVis 2022-08-19       2022-08-18 2022-08-10        1.0
# 0         tensorflow 2022-08-19       2022-08-19 2015-11-07      353.0
# 74          pyscript 2022-08-19       2022-08-18 2022-02-21       25.0
# 1      TheAlgorithms 2022-08-19       2022-08-16 2016-07-16      317.0
# 124        bloomberg 2022-08-19       2022-08-18 2022-04-08       19.0
# ...              ...        ...              ...        ...        ...
# 698            irmen 2022-07-28       2022-08-13 2019-06-30      163.0
# 657    openaddresses 2022-08-17       2022-06-19 2013-12-06      454.0
# 688        guyallard 2022-08-11       2018-12-11 2017-09-27      255.0
# 642          mgedmin 2022-08-07       2022-05-30 2013-03-05      493.0
# total            NaN        NaT              NaT        NaT   190077.0
#
#        stars_per_week  watches_per_week  forks_per_week  stars_percent  \
# 206       4181.333333        114.000000      397.000000       0.127762
# 0          472.501413         22.150142      246.688385       3.973496
# 74         557.653631          7.080000       40.520000       0.338892
# 1          447.657079         18.977918      115.015773       3.381576
# 124        478.210526          2.789474       12.842105       0.215931
# ...               ...               ...             ...            ...
# 698          0.623037          0.018405        0.067485       0.002424
# 657          0.515419          0.033040        0.125551       0.005561
# 688          0.497482          0.035294        0.133333       0.003018
# 642          0.533005          0.012170        0.073022       0.006250
# total    23371.565411        562.472242     3700.450234     100.000000
#
#        watches_percent  forks_percent
# 206           0.098864       0.043818
# 0             6.780852       9.611335
# 74            0.153499       0.111807
# 1             5.217240       4.024176
# 124           0.045963       0.026931
# ...                ...            ...
# 698           0.002602       0.001214
# 657           0.013008       0.006291
# 688           0.007805       0.003753
# 642           0.005203       0.003973
# total       100.000000     100.000000
#
# [700 rows x 28 columns]

# %%
print(f"{len(df)=}")
print(f"{df.dtypes=}")
display(pd.concat([df[0:10], df[-1:]]))
# Out:
# len(df)=700
# df.dtypes=popularity_measure           float64
# category                      object
# githuburl                     object
# featured                     float64
# links                         object
# description                  float64
# description                   object
# repopath                      object
# reponame                      object
# stars                        float64
# forks                        float64
# watches                      float64
# topics                        object
# language                      object
# homepage                      object
# description                  float64
# description                   object
# organization                  object
# updated_at            datetime64[ns]
# last_commit_date      datetime64[ns]
# created_at            datetime64[ns]
# age_weeks                    float64
# stars_per_week               float64
# watches_per_week             float64
# forks_per_week               float64
# stars_percent                float64
# watches_percent              float64
# forks_percent                float64
# dtype: object
#        popularity_measure category  \
# 206           5887.000000    ml-dl
# 0              742.487252    ml-dl
# 74             618.000000      web
# 1              582.861199     util
# 124            493.842105     perf
# 2              431.328283      nlp
# 163            412.052632    ml-dl
# 36             334.405405       ml
# 14             284.937500     term
# 9              275.317708      web
# total        28945.120754      NaN
#
#                                           githuburl  featured links  \
# 206     https://github.com/CompVis/stable-diffusion       NaN   NaN
# 0          https://github.com/tensorflow/tensorflow       NaN   NaN
# 74             https://github.com/pyscript/pyscript       NaN   NaN
# 1           https://github.com/TheAlgorithms/Python       NaN   NaN
# 124             https://github.com/bloomberg/memray       NaN   NaN
# 2       https://github.com/huggingface/transformers       NaN   NaN
# 163    https://github.com/lucidrains/DALLE2-pytorch       NaN   NaN
# 36             https://github.com/TencentARC/GFPGAN       NaN   NaN
# 14              https://github.com/willmcgugan/rich       NaN   NaN
# 9               https://github.com/tiangolo/fastapi       NaN   NaN
# total                                           NaN      23.0   NaN
#
#       description                                        description  \
# 206           NaN                           CompVis/stable-diffusion
# 0             NaN  tensorflow: An Open Source Machine Learning Fr...
# 74            NaN  pyscript: Home Page: https://pyscript.net  Exa...
# 1             NaN       Python: All Algorithms implemented in Python
# 124           NaN             Memray is a memory profiler for Python
# 2             NaN  🤗 Transformers: State-of-the-art Machine Learn...
# 163           NaN  DALLE2-pytorch: Implementation of DALL-E 2, Op...
# 36            NaN  GFPGAN aims at developing Practical Algorithms...
# 14            NaN  Rich is a Python library for rich text and bea...
# 9             NaN  FastAPI framework, high performance, easy to l...
# total         0.0                                                NaN
#
#                         repopath          reponame      stars     forks  \
# 206     CompVis/stable-diffusion  stable-diffusion     5376.0     397.0
# 0          tensorflow/tensorflow        tensorflow   167198.0   87081.0
# 74             pyscript/pyscript          pyscript    14260.0    1013.0
# 1           TheAlgorithms/Python            Python   142291.0   36460.0
# 124             bloomberg/memray            memray     9086.0     244.0
# 2       huggingface/transformers      transformers    68665.0   15893.0
# 163    lucidrains/DALLE2-pytorch    DALLE2-pytorch     7206.0     520.0
# 36             TencentARC/GFPGAN            GFPGAN    21215.0    3210.0
# 14              willmcgugan/rich              rich    39176.0    1324.0
# 9               tiangolo/fastapi           fastapi    48422.0    3845.0
# total                        NaN               NaN  4207831.0  906024.0
#
#         watches                                             topics  \
# 206       114.0                                                 []
# 0        7819.0  ['tensorflow', 'machine-learning', 'python', '...
# 74        177.0                   ['python', 'html', 'javascript']
# 1        6016.0  ['python', 'algorithm', 'algorithms-implemente...
# 124        53.0  ['memory', 'memory-leak', 'memory-leak-detecti...
# 2         845.0  ['nlp', 'natural-language-processing', 'pytorc...
# 163       103.0  ['artificial-intelligence', 'deep-learning', '...
# 36        321.0  ['pytorch', 'gan', 'deep-learning', 'super-res...
# 14        531.0  ['python', 'python3', 'python-library', 'termi...
# 9         594.0  ['python', 'json', 'swagger-ui', 'redoc', 'sta...
# total  115310.0                                                NaN
#
#                language                                           homepage  \
# 206    Jupyter Notebook                                                NaN
# 0                   C++                             https://tensorflow.org
# 74           TypeScript  https://community.anaconda.cloud/c/tech-topics...
# 1                Python                        https://the-algorithms.com/
# 124              Python                https://bloomberg.github.io/memray/
# 2                Python                https://huggingface.co/transformers
# 163              Python                                                NaN
# 36               Python                                                NaN
# 14               Python             https://rich.readthedocs.io/en/latest/
# 9                Python                      https://fastapi.tiangolo.com/
# total               NaN                                                NaN
#
#       description                                        description  \
# 206           NaN                           CompVis/stable-diffusion
# 0             NaN  tensorflow: An Open Source Machine Learning Fr...
# 74            NaN  pyscript: Home Page: https://pyscript.net  Exa...
# 1             NaN       Python: All Algorithms implemented in Python
# 124           NaN             Memray is a memory profiler for Python
# 2             NaN  🤗 Transformers: State-of-the-art Machine Learn...
# 163           NaN  DALLE2-pytorch: Implementation of DALL-E 2, Op...
# 36            NaN  GFPGAN aims at developing Practical Algorithms...
# 14            NaN  Rich is a Python library for rich text and bea...
# 9             NaN  FastAPI framework, high performance, easy to l...
# total         0.0                                                NaN
#
#         organization updated_at last_commit_date created_at  age_weeks  \
# 206          CompVis 2022-08-19       2022-08-18 2022-08-10        1.0
# 0         tensorflow 2022-08-19       2022-08-19 2015-11-07      353.0
# 74          pyscript 2022-08-19       2022-08-18 2022-02-21       25.0
# 1      TheAlgorithms 2022-08-19       2022-08-16 2016-07-16      317.0
# 124        bloomberg 2022-08-19       2022-08-18 2022-04-08       19.0
# 2        huggingface 2022-08-19       2022-08-18 2018-10-29      198.0
# 163       lucidrains 2022-08-19       2022-08-17 2022-04-07       19.0
# 36        TencentARC 2022-08-19       2022-07-13 2021-03-19       74.0
# 14       willmcgugan 2022-08-19       2022-08-17 2019-11-10      144.0
# 9           tiangolo 2022-08-19       2022-08-18 2018-12-08      192.0
# total            NaN        NaT              NaT        NaT   190077.0
#
#        stars_per_week  watches_per_week  forks_per_week  stars_percent  \
# 206       4181.333333        114.000000      397.000000       0.127762
# 0          472.501413         22.150142      246.688385       3.973496
# 74         557.653631          7.080000       40.520000       0.338892
# 1          447.657079         18.977918      115.015773       3.381576
# 124        478.210526          2.789474       12.842105       0.215931
# 2          345.794964          4.267677       80.267677       1.631838
# 163        376.432836          5.421053       27.368421       0.171252
# 36         286.689189          4.337838       43.378378       0.504179
# 14         270.712734          3.687500        9.194444       0.931026
# 9          251.077037          3.093750       20.026042       1.150759
# total    23371.565411        562.472242     3700.450234     100.000000
#
#        watches_percent  forks_percent
# 206           0.098864       0.043818
# 0             6.780852       9.611335
# 74            0.153499       0.111807
# 1             5.217240       4.024176
# 124           0.045963       0.026931
# 2             0.732807       1.754148
# 163           0.089324       0.057394
# 36            0.278380       0.354295
# 14            0.460498       0.146133
# 9             0.515133       0.424382
# total       100.000000     100.000000

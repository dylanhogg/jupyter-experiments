# %% [markdown]
# <a href="https://colab.research.google.com/github/dylanhogg/jupyter-experiments/blob/master/colab/ukplab/sentence-transformers-v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ukplab/sentence-transformers example
#
# https://github.com/ukplab/sentence-transformers
#
# Sentence Transformers: Multilingual Sentence, Paragraph, and Image Embeddings using BERT & Co.
#
# This framework provides an easy method to compute dense vector representations for sentences, paragraphs, and images. The models are based on transformer networks like BERT / RoBERTa / XLM-RoBERTa etc. and achieve state-of-the-art performance in various task. Text is embedding in vector space such that similar text is close and can efficiently be found using cosine similarity.

# %% [markdown]
# # Install required packages

# %%
# %pip install sentence-transformers -q  # Install github.com/ukplab/sentence-transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 58.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 85.1 MB/s eta 0:00:00
#   Building wheel for sentence-transformers (setup.py) ... done

# %% [markdown]
# # Imports

# %%
import math
import json
import numpy as np
import pandas as pd
from datetime import datetime
from functools import wraps
from IPython.display import display, HTML

# %% [markdown]
# # Load dataframe

# %%
df = pd.read_json("https://www.awesomepython.org/github_data.json", orient="table")

# %%
df[["_repopath", "_readme_localurl", "_readme_giturl", "_readme_filename"]]
# Out:
#                                 _repopath  \
# 89                  tensorflow/tensorflow
# 112              huggingface/transformers
# 76                        pytorch/pytorch
# 189                   home-assistant/core
# 957                    charliermarsh/ruff
# ...                                   ...
# 994                 zackeskin/pycausality
# 1150  geeogi/async-python-lambda-template
# 520                   lydorn/mapalignment
# 180                         artemyk/dynpy
# 525                     lycantropos/wagyu
#
#                                    _readme_localurl  \
# 89                  tensorflow~tensorflow~README.md
# 112              huggingface~transformers~README.md
# 76                        pytorch~pytorch~README.md
# 189                  home-assistant~core~README.rst
# 957                    charliermarsh~ruff~README.md
# ...                                             ...
# 994                 zackeskin~pycausality~README.md
# 1150  geeogi~async-python-lambda-template~README.md
# 520                   lydorn~mapalignment~README.md
# 180                         artemyk~dynpy~README.md
# 525                     lycantropos~wagyu~README.md
#
#                                          _readme_giturl _readme_filename
# 89    https://raw.githubusercontent.com/tensorflow/t...        README.md
# 112   https://raw.githubusercontent.com/huggingface/...        README.md
# 76    https://raw.githubusercontent.com/pytorch/pyto...        README.md
# 189   https://raw.githubusercontent.com/home-assista...       README.rst
# 957   https://raw.githubusercontent.com/charliermars...        README.md
# ...                                                 ...              ...
# 994   https://raw.githubusercontent.com/zackeskin/py...        README.md
# 1150  https://raw.githubusercontent.com/geeogi/async...        README.md
# 520   https://raw.githubusercontent.com/lydorn/mapal...        README.md
# 180   https://raw.githubusercontent.com/artemyk/dynp...        README.md
# 525   https://raw.githubusercontent.com/lycantropos/...        README.md
#
# [1357 rows x 4 columns]

# %% [markdown]
# # Calculate Similarity

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
records = df[["_repopath", "_reponame", "category", "_description", "_topics"]].to_dict("records")

# %%
def remove_generic_topics(topics):
    remove_topics = ["python", "python2", "python-2", "python3", "python-3", "python-library", "library"]
    for t in remove_topics:
        if t in topics:
            topics.remove(t)
    return topics

# %%
def create_similarity_record(row):
    topics = remove_generic_topics(row["_topics"])
    description = row['_description']
    description = description.replace(row['_reponame'] + ': ', "")  # HACK: remove prefixed repo name from description
    
    description = description.strip().rstrip(".")
    description += ". " + row["category"]
    description += ", " + ", ".join(topics)
    
    return {"repopath": row["_repopath"], "sentence": description, "topics": topics}

# %%
similarity_records = [create_similarity_record(v) for v in records]

# %%
similarity_records[0:1]
# Out:
# [{'repopath': 'tensorflow/tensorflow',
#   'sentence': 'An Open Source Machine Learning Framework for Everyone. ml-dl, tensorflow, machine-learning, deep-learning, deep-neural-networks, neural-network, ml, distributed',
#   'topics': ['tensorflow',
#    'machine-learning',
#    'deep-learning',
#    'deep-neural-networks',
#    'neural-network',
#    'ml',
#    'distributed']}]

# %%
sentences = [d["sentence"] for d in similarity_records]

# %%
embeddings = model.encode(sentences, show_progress_bar=True)
cos_sim = util.cos_sim(embeddings, embeddings)  # Returns torch.Tensor
# Out:
# Batches:   0%|          | 0/43 [00:00<?, ?it/s]

# %%
cos_sim[0:2]
# Out:
# tensor([[1.0000, 0.6089, 0.5181,  ..., 0.0997, 0.1834, 0.1511],
#         [0.6089, 1.0000, 0.4545,  ..., 0.0414, 0.2857, 0.2346]])

# %%
# Add all pairs to a list with their cosine similarity score
pairs = []
for i, x in enumerate(cos_sim):
    for j, x in enumerate(cos_sim):
        if i != j:  # Exclude identity
            pairs.append([float(cos_sim[i][j]), i, j])

# %%
# Sort list by the highest cosine similarity score
pairs = sorted(pairs, key=lambda x: x[0], reverse=True)

# %%
# Construct lookup_dict and pairwise_dataset
pairwise_dataset = []
lookup_dict = {}
sim_cutoff = 0.50  # TODO: review, mostly crap below 0.65
for idx, (score, i, j) in enumerate(pairs):
    common_topics = list(set(similarity_records[i]["topics"]) & set(similarity_records[j]["topics"]))
    total_topics = len(set(similarity_records[i]["topics"])) + len(set(similarity_records[j]["topics"]))
    sim = float(cos_sim[i][j])
    if sim > sim_cutoff:
        repo1 = similarity_records[i]["repopath"]
        repo2 = similarity_records[j]["repopath"]
        lookup_dict.setdefault(repo1,[]).append((repo2, sim))
        pairwise_dataset.append({
            "idx": idx, 
            "sim": sim, 
            "common_topics": ", ".join(common_topics),
            "common_topics_count": len(common_topics),
            "total_topics_count": total_topics,
            "common_topics_prop": len(common_topics) / total_topics if total_topics > 0 else 0,
            "repo1": repo1,
            "repo2": repo2,
            "sent1": similarity_records[i]["sentence"], 
            "sent2": similarity_records[j]["sentence"],
        })
# Ensure sorted dict value by similarity (item[1])
lookup_dict = {k: sorted(v, key=lambda item: item[1], reverse=True) for k, v in lookup_dict.items()}

# %% [markdown]
# # Inspect lookup_dict

# %%
len(lookup_dict)
# Out:
# 1271

# %%
lookup_dict["pallets/flask"]
# Out:
# [('bottlepy/bottle', 0.7904598712921143),
#  ('pallets/werkzeug', 0.7790221571922302),
#  ('pylons/pyramid', 0.7733316421508789),
#  ('pallets/quart', 0.746427059173584),
#  ('webpy/webpy', 0.7430812120437622),
#  ('pynecone-io/pynecone', 0.7326019406318665),
#  ('falconry/falcon', 0.705865740776062),
#  ('klen/muffin', 0.7026605010032654),
#  ('flet-dev/flet', 0.6750704050064087),
#  ('neoteroi/blacksheep', 0.6668559312820435),
#  ('r0x0r/pywebview', 0.6623570919036865),
#  ('python-restx/flask-restx', 0.6471693515777588),
#  ('cherrypy/cherrypy', 0.6420167088508606),
#  ('encode/uvicorn', 0.6244233846664429),
#  ('emmett-framework/emmett', 0.622439444065094),
#  ('ets-labs/python-dependency-injector', 0.6025866270065308),
#  ('django/django', 0.592947244644165),
#  ('pylons/waitress', 0.5921154618263245),
#  ('scrapy/scrapy', 0.5911469459533691),
#  ('dylanhogg/python-project-template', 0.5901235342025757),
#  ('huge-success/sanic', 0.5831112265586853),
#  ('vinta/awesome-python', 0.5806543827056885),
#  ('pyeve/eve', 0.5805999040603638),
#  ('plotly/dash', 0.576889157295227),
#  ('benoitc/gunicorn', 0.5761930346488953),
#  ('backtick-se/cowait', 0.5740963220596313),
#  ('vitalik/django-ninja', 0.5739825367927551),
#  ('voila-dashboards/voila', 0.5705416202545166),
#  ('clips/pattern', 0.5649174451828003),
#  ('encode/httpx', 0.5622530579566956),
#  ('pyodide/pyodide', 0.5611722469329834),
#  ('encode/starlette', 0.5571173429489136),
#  ('psf/requests', 0.5496665239334106),
#  ('seleniumbase/seleniumbase', 0.5492305159568787),
#  ('indygreg/pyoxidizer', 0.54839026927948),
#  ('timofurrer/awesome-asyncio', 0.548152506351471),
#  ('starlite-api/starlite', 0.5476027131080627),
#  ('micropython/micropython', 0.5462173223495483),
#  ('kivy/kivy', 0.542320191860199),
#  ('aio-libs/aiohttp', 0.5413507223129272),
#  ('amaargiru/pyroad', 0.5407440662384033),
#  ('pypa/hatch', 0.5406377911567688),
#  ('pyodide/micropip', 0.5326385498046875),
#  ('willmcgugan/textual', 0.5320810675621033),
#  ('google/gin-config', 0.5319452285766602),
#  ('goldmansachs/gs-quant', 0.5306185483932495),
#  ('tiangolo/fastapi', 0.5287648439407349),
#  ('dylanhogg/awesome-python', 0.5252895355224609),
#  ('tiangolo/full-stack-fastapi-postgresql', 0.5227177143096924),
#  ('reloadware/reloadium', 0.5212963819503784),
#  ('python/cpython', 0.5207170844078064),
#  ('pywebio/pywebio', 0.5183592438697815),
#  ('nficano/python-lambda', 0.5152173042297363),
#  ('rstudio/py-shiny', 0.5150683522224426),
#  ('hoffstadt/dearpygui', 0.5139194130897522),
#  ('dagworks-inc/hamilton', 0.5132532119750977),
#  ('eleutherai/pyfra', 0.5116252899169922),
#  ('pyscript/pyscript-cli', 0.5084113478660583),
#  ('graphql-python/graphene', 0.5070014595985413),
#  ('pyscript/pyscript', 0.5060468316078186),
#  ('tornadoweb/tornado', 0.5045236349105835),
#  ('wtforms/wtforms', 0.5028114318847656),
#  ('pylons/webob', 0.5024668574333191),
#  ('holoviz/panel', 0.5015721321105957),
#  ('pyston/pyston', 0.5012146234512329),
#  ('omry/omegaconf', 0.5011695027351379)]

# %%
lookup_dict["pytorch/pytorch"]
# Out:
# [('tensorly/tensorly', 0.6504698991775513),
#  ('xl0/lovely-tensors', 0.6335645914077759),
#  ('google/tf-quant-finance', 0.6253831386566162),
#  ('arogozhnikov/einops', 0.6087567806243896),
#  ('google/jax', 0.59925776720047),
#  ('intel/intel-extension-for-pytorch', 0.5928418636322021),
#  ('huggingface/accelerate', 0.5912996530532837),
#  ('cupy/cupy', 0.583601713180542),
#  ('neuralmagic/deepsparse', 0.5795375108718872),
#  ('facebookincubator/aitemplate', 0.5757184028625488),
#  ('rafiqhasan/auto-tensorflow', 0.5696676969528198),
#  ('nyandwi/modernconvnets', 0.5640577077865601),
#  ('lightly-ai/lightly', 0.5578372478485107),
#  ('ageron/handson-ml2', 0.5575507879257202),
#  ('karpathy/micrograd', 0.5568565130233765),
#  ('pytorch/glow', 0.5523102283477783),
#  ('pytorch/ignite', 0.5516836643218994),
#  ('plasma-umass/scalene', 0.5511540770530701),
#  ('tensorflow/addons', 0.5481816530227661),
#  ('ddbourgin/numpy-ml', 0.5463129281997681),
#  ('facebookresearch/pytorch3d', 0.5412343740463257),
#  ('nebuly-ai/nebullvm', 0.536312460899353),
#  ('skorch-dev/skorch', 0.530871570110321),
#  ('dmlc/dgl', 0.5287739038467407),
#  ('tensorlayer/tensorlayer', 0.5253920555114746),
#  ('keras-team/autokeras', 0.5245634317398071),
#  ('keras-rl/keras-rl', 0.5231357216835022),
#  ('xl0/lovely-numpy', 0.5229644775390625),
#  ('patrick-kidger/torchtyping', 0.522266149520874),
#  ('pycaret/pycaret', 0.5200274586677551),
#  ('tensorflow/mesh', 0.5189484357833862),
#  ('tensorflow/tensorflow', 0.5181211233139038),
#  ('google/trax', 0.5175195932388306),
#  ('cvxgrp/pymde', 0.5166696906089783),
#  ('exaloop/codon', 0.5166019201278687),
#  ('mosaicml/composer', 0.5144997835159302),
#  ('scikit-learn/scikit-learn', 0.5093284845352173),
#  ('explosion/thinc', 0.5091843605041504),
#  ('tensorflow/similarity', 0.5087348818778992),
#  ('horovod/horovod', 0.5083086490631104),
#  ('rentruewang/koila', 0.5077421069145203),
#  ('nvidia/deeplearningexamples', 0.5047619938850403),
#  ('ray-project/ray', 0.5035560131072998),
#  ('micropython/micropython', 0.5032979249954224),
#  ('nicolas-chaulet/torch-points3d', 0.5029953718185425),
#  ('eleutherai/gpt-neo', 0.5026659369468689),
#  ('tlkh/tf-metal-experiments', 0.5016522407531738),
#  ('pyg-team/pytorch_geometric', 0.5006177425384521)]

# %% [markdown]
# # Add back to df

# %%
# Add back to df
def lookup_similarity_record(row, lookup_dict, sim_cutoff):
    lookup = lookup_dict.get(row['_repopath'], None)
    result = [] if lookup is None else [x[0] for x in lookup if x[1] >= sim_cutoff]
    return result

df["sim"] = df.apply(
        lambda row: lookup_similarity_record(row, lookup_dict, sim_cutoff=sim_cutoff), axis=1,
    )

# %%
df[["_repopath", "_description", "sim"]]
# Out:
#                                 _repopath  \
# 89                  tensorflow/tensorflow
# 112              huggingface/transformers
# 76                        pytorch/pytorch
# 189                   home-assistant/core
# 957                    charliermarsh/ruff
# ...                                   ...
# 994                 zackeskin/pycausality
# 1150  geeogi/async-python-lambda-template
# 520                   lydorn/mapalignment
# 180                         artemyk/dynpy
# 525                     lycantropos/wagyu
#
#                                            _description  \
# 89    An Open Source Machine Learning Framework for ...
# 112   🤗 Transformers: State-of-the-art Machine Learn...
# 76    Tensors and Dynamic neural networks in Python ...
# 189   🏡 Open source home automation that puts local ...
# 957   An extremely fast Python linter, written in Rust.
# ...                                                 ...
# 994   Calculate predictive causality between time se...
# 1150  Build a high-performance Python function in AW...
# 520   Aligning and Updating Cadaster Maps with Remot...
# 180                        Dynamical systems for Python
# 525   Python port of mapbox/wagyu library (with sepa...
#
#                                                     sim
# 89    [mlflow/mlflow, keras-team/keras, alpa-project...
# 112   [arogozhnikov/einops, huggingface/datasets, ex...
# 76    [tensorly/tensorly, xl0/lovely-tensors, google...
# 189   [blakeblackshear/frigate, home-assistant/super...
# 957   [google/pytype, pola-rs/polars, pycqa/pylint, ...
# ...                                                 ...
# 994                                                  []
# 1150  [jordaneremieff/mangum, nficano/python-lambda,...
# 520                                 [zorzi-s/maprepair]
# 180   [projectmesa/mesa, crflynn/stochastic, bilhim/...
# 525                                                  []
#
# [1357 rows x 3 columns]
